# %%
import pickle

import numpy as np
import matplotlib as mpl
# %matplotlib inline
import matplotlib.pyplot as plt

mpl.rcParams['xtick.labelsize'] = 13
mpl.rcParams['ytick.labelsize'] = 13

# %%
with open('./data/cifar10_scatter100_resnet.pkl','rb') as f:
    data100 = pickle.load(f)
    data100 = np.asarray(data100)
    
with open('./data/cifar10/cifar10_resnet_1000_scatter.pkl','rb') as f:
    data1000 = pickle.load(f)
    data1000 = np.asarray(data500)
    
with open('./data/cifar10-scatter5000-resnet.pkl','rb') as f:
    data5000 = pickle.load(f)
    data5000 = np.asarray(data5000)

# %%
plt.plot(data100[:,3],data100[:,4],'or',markersize=10,label='n=100')
# plt.plot(data1000[:,3],data1000[:,4],'o',markersize=10)
plt.plot(data5000[:,3],data5000[:,4],'*b',markersize=10,label='n=5000')

plt.xlabel('Sharpness',fontsize=22)
plt.ylabel('Non-uniformity',fontsize=22)
plt.title('ResNet for CIFAR10',fontsize=22)
plt.legend(fontsize=20)
plt.savefig('figures/resnet-cifar.pdf',bbox_inches='tight')

# %%
plt.plot(data[:,3],data[:,6],'ok',markersize=10)
plt.xlabel('Sharpness',fontsize=22)
plt.ylabel('Test Accuracy',fontsize=22)
plt.title('ResNet',fontsize=22)
plt.savefig('figures/resnet-cifar-sharpness-teacc.pdf',bbox_inches='tight')

# %%
data1000
# Out:
# array([], dtype=float64)
